# %%
import pandas as pd
from neo4j import GraphDatabase
from neo4j.exceptions import DriverError, Neo4jError

# %%
df = pd.read_csv('SP_500_ESG_Risk_Ratings.csv')
df.dropna(inplace=True)
df.drop(['ESG Risk Percentile', 'Description'], inplace=True, axis=1)
df
# Out:
#     Symbol                      Name  \
# 0        A  Agilent Technologies Inc
# 2      AAP    Advance Auto Parts Inc
# 3     AAPL                 Apple Inc
# 4     ABBV                Abbvie Inc
# 5      ABC    Amerisourcebergen Corp
# ..     ...                       ...
# 495    XEL           Xcel Energy Inc
# 496   XRAY       Dentsply Sirona Inc
# 497    XYL                 Xylem Inc
# 498    YUM            Yum Brands Inc
# 502    ZTS                Zoetis Inc
#
#                                                Address             Sector  \
# 0    5301 Stevens Creek Boulevard\nSanta Clara, CA ...         Healthcare
# 2    4200 Six Forks Road\nRaleigh, NC 27609\nUnited...  Consumer Cyclical
# 3    One Apple Park Way\nCupertino, CA 95014\nUnite...         Technology
# 4    1 North Waukegan Road\nNorth Chicago, IL 60064...         Healthcare
# 5    1 West First Avenue\nConshohocken, PA 19428-18...         Healthcare
# ..                                                 ...                ...
# 495  414 Nicollet Mall\nMinneapolis, MN 55401\nUnit...          Utilities
# 496  13320 Ballantyne Corporate Place\nCharlotte, N...         Healthcare
# 497  300 Water Street SE\nWashington, DC 20003\nUni...        Industrials
# 498  1441 Gardiner Lane\nLouisville, KY 40213\nUnit...  Consumer Cyclical
# 502  10 Sylvan Way\nParsippany, NJ 07054\nUnited St...         Healthcare
#
#                                    Industry Full Time Employees  \
# 0                    Diagnostics & Research              18,000
# 2                          Specialty Retail              40,000
# 3                      Consumer Electronics             164,000
# 4                Drug Manufacturers—General              50,000
# 5                      Medical Distribution              46,000
# ..                                      ...                 ...
# 495            Utilities—Regulated Electric              11,982
# 496          Medical Instruments & Supplies              15,000
# 497          Specialty Industrial Machinery              22,000
# 498                             Restaurants              36,000
# 502  Drug Manufacturers—Specialty & Generic              13,800
#
#      Total ESG Risk score  Environment Risk Score  Governance Risk Score  \
# 0                    15.0                     0.3                    6.3
# 2                    12.0                     0.0                    3.0
# 3                    17.0                     0.6                    9.2
# 4                    28.0                     1.1                    9.9
# 5                    12.0                     1.3                    5.2
# ..                    ...                     ...                    ...
# 495                  24.0                    12.9                    4.2
# 496                  16.0                     2.0                    7.0
# 497                  16.0                     4.0                    5.0
# 498                  21.0                     4.5                    4.4
# 502                  18.0                     1.4                    8.9
#
#      Social Risk Score Controversy Level  Controversy Score ESG Risk Level
# 0                  8.6               Low                1.0            Low
# 2                  8.0          Moderate                2.0     Negligible
# 3                  6.9       Significant                3.0            Low
# 4                 16.8       Significant                3.0         Medium
# 5                  5.6       Significant                3.0            Low
# ..                 ...               ...                ...            ...
# 495                6.8          Moderate                2.0         Medium
# 496                7.0               Low                1.0     Negligible
# 497                7.0               Low                1.0     Negligible
# 498               11.6          Moderate                2.0         Medium
# 502                8.1               Low                1.0            Low
#
# [347 rows x 13 columns]

# %%
class CompaniesFiller:
    def __init__(self, uri, user, password, database = None):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))
        self.database = database
    
    def create_companies(self, companies_df: pd.DataFrame):
        with self.driver.session() as session:
            for row in companies_df.iterrows():
                result = self._create_and_return_company(row[1])
                print(f'Created company: {result}')
            
    
    def _create_and_return_company(self, company_data):
        query = (
            "CREATE (cmp:Company { name: $company_name }) "
            "CREATE (sym:Symbol { name: $symbol }) "
            "CREATE (cmp)-[:SYMBOL]->(sym) "
            "CREATE (adr:Address { name: $address }) "
            "CREATE (cmp)-[:ADDRESS]->(adr) "
            "CREATE (sct:Sector { name: $sector }) "
            "CREATE (cmp)-[:SECTOR]->(sct) "
            "CREATE (ind:Industry { name: $industry }) "
            "CREATE (cmp)-[:INDUSTRY]->(ind) "
            "CREATE (emp:Number {value: $emp_amount}) "
            "CREATE (cmp)-[:EMPLOYEE_AMOUNT]->(emp) "
            "CREATE (esg_r_score:Number { value: $risk_score }) "            
            "CREATE (cmp)-[:RISK_SCORE]->(esg_r_score) "
            "CREATE (ct_level:Controversy_Level { value: $controversy_level }) "
            "CREATE (cmp)-[:CONTROVERSY_LEVEL]->(ct_level) "
            "CREATE (ct_score:Number { value: $controversy_score }) "
            "CREATE (cmp)-[:CONTROVERSY_SCORE]->(ct_score) "
            "RETURN cmp.name"
        )
        try:
            record = self.driver.execute_query(
                query_=query,
                company_name=company_data['Name'],
                symbol=company_data['Symbol'],
                address=company_data['Address'],
                sector=company_data['Sector'],
                industry=company_data['Industry'],
                emp_amount=int(company_data['Full Time Employees'].replace(',', '')),
                risk_score=company_data['Total ESG Risk score'],
                controversy_level=company_data['Controversy Level'],
                controversy_score=company_data['Controversy Score'],
                database_=self.database,
                result_transformer_=lambda r: r.single(strict=True)                
            )
            return record['cmp.name']
        except (DriverError, Neo4jError) as err:
            print(f'Error during query: {err}')
    
    def close(self):
        self.driver.close()

# %%
URI = 'bolt://localhost:7687'
USER = 'neo4j'
PASSWORD = 'ilikepkb'
DATABASE = 'companies'

db_filler = CompaniesFiller(URI, USER, PASSWORD, DATABASE)

# %%
try:
    db_filler.create_companies(df)
finally:
    db_filler.close()
# Out:
# Created company: Agilent Technologies Inc
# Created company: Advance Auto Parts Inc
# Created company: Apple Inc
# Created company: Abbvie Inc
# Created company: Amerisourcebergen Corp
# Created company: Abbott Laboratories
# Created company: Accenture Plc Cl A
# Created company: Adobe Inc
# Created company: Archer Daniels Midland Co
# Created company: Automatic Data Processing
# Created company: Ameren Corporation
# Created company: Aes Corp
# Created company: Aflac Inc
# Created company: Arthur J Gallagher & Co
# Created company: Akamai Technologies Inc
# Created company: Allstate Corp
# Created company: Applied Materials Inc
# Created company: Ametek Inc
# Created company: Amgen Inc
# Created company: Ameriprise Financial Inc
# Created company: American Tower Corp
# Created company: Amazon.com Inc
# Created company: Arista Networks Inc
# Created company: Apa Corp
# Created company: Air Products & Chemicals Inc
# Created company: Amphenol Corp Cl A
# Created company: Aptiv Plc
# Created company: Atmos Energy Corp
# Created company: Activision Blizzard Inc
# Created company: Avalonbay Communities Inc
# Created company: Broadcom Inc
# Created company: Avery Dennison Corp
# Created company: American Express Co
# Created company: Autozone Inc
# Created company: Boeing Co
# Created company: Bank of America Corp
# Created company: Ball Corp
# Created company: Baxter International Inc
# Created company: Bath & Body Works Inc
# Created company: Best Buy Co Inc
# Created company: Becton Dickinson and Co
# Created company: Franklin Resources Inc
# Created company: Bunge Ltd
# Created company: Biogen Inc
# Created company: Bio Rad Laboratories A
# Created company: Bank of New York Mellon Corp
# Created company: Booking Holdings Inc
# Created company: Blackrock Inc
# Created company: Bristol Myers Squibb Co
# Created company: Broadridge Financial Solutio
# Created company: Brown & Brown Inc
# Created company: Boston Scientific Corp
# Created company: Borgwarner Inc
# Created company: Boston Properties Inc
# Created company: Citigroup Inc
# Created company: Conagra Brands Inc
# Created company: Cardinal Health Inc
# Created company: Chubb Ltd
# Created company: Cboe Global Markets Inc
# Created company: Carnival Corp
# Created company: Celanese Corp
# Created company: Cf Industries Holdings Inc
# Created company: Citizens Financial Group
# Created company: Church & Dwight Co Inc
# Created company: The Cigna Group
# Created company: Cincinnati Financial Corp
# Created company: Colgate Palmolive Co
# Created company: Clorox Company
# Created company: Comcast Corp Class A
# Created company: Cme Group Inc
# Created company: Chipotle Mexican Grill Inc
# Created company: Cummins Inc
# Created company: Cms Energy Corp
# Created company: Centene Corp
# Created company: Centerpoint Energy Inc
# Created company: Cooper Cos Inc
# Created company: Conocophillips
# Created company: Costco Wholesale Corp
# Created company: Copart Inc
# Created company: Camden Property Trust
# Created company: Salesforce Inc
# Created company: Costar Group Inc
# Created company: Csx Corp
# Created company: Cintas Corp
# Created company: Coterra Energy Inc
# Created company: Cognizant Tech Solutions A
# Created company: Cvs Health Corp
# Created company: Chevron Corp
# Created company: Dominion Energy Inc
# Created company: Dupont De Nemours Inc
# Created company: Deere & Co
# Created company: Dollar General Corp
# Created company: Quest Diagnostics Inc
# Created company: Dr Horton Inc
# Created company: Danaher Corp
# Created company: Walt Disney Co
# Created company: Dollar Tree Inc
# Created company: Dover Corp
# Created company: Domino S Pizza Inc
# Created company: Darden Restaurants Inc
# Created company: Dte Energy Company
# Created company: Duke Energy Corp
# Created company: Devon Energy Corp
# Created company: Dxc Technology Co
# Created company: Electronic Arts Inc
# Created company: Ebay Inc
# Created company: Consolidated Edison Inc
# Created company: Estee Lauder Companies Cl A
# Created company: Elevance Health Inc
# Created company: Emerson Electric Co
# Created company: Eog Resources Inc
# Created company: Equinix Inc
# Created company: Equity Residential
# Created company: Eqt Corp
# Created company: Eversource Energy
# Created company: Essex Property Trust Inc
# Created company: Eaton Corp Plc
# Created company: Entergy Corp
# Created company: Edwards Lifesciences Corp
# Created company: Exelon Corp
# Created company: Expeditors Intl Wash Inc
# Created company: Expedia Group Inc
# Created company: Extra Space Storage Inc
# Created company: Ford Motor Co
# Created company: Fastenal Co
# Created company: Freeport Mcmoran Inc
# Created company: Factset Research Systems Inc
# Created company: Fedex Corp
# Created company: Firstenergy Corp
# Created company: F5 Inc
# Created company: Fidelity National Info Serv
# Created company: Fifth Third Bancorp
# Created company: Fleetcor Technologies Inc
# Created company: Fmc Corp
# Created company: Federal Realty Invs Trust
# Created company: Fortinet Inc
# Created company: Fortive Corp
# Created company: General Dynamics Corp
# Created company: General Electric Co
# Created company: Gen Digital Inc
# Created company: Gilead Sciences Inc
# Created company: Corning Inc
# Created company: General Motors Co
# Created company: Alphabet Inc Cl A
# Created company: Genuine Parts Co
# Created company: Global Payments Inc
# Created company: Garmin Ltd
# Created company: Goldman Sachs Group Inc
# Created company: Ww Grainger Inc
# Created company: Halliburton Co
# Created company: Huntington Bancshares Inc
# Created company: Hca Healthcare Inc
# Created company: Home Depot Inc
# Created company: Hess Corp
# Created company: Hartford Financial Svcs Grp
# Created company: Hilton Worldwide Holdings In
# Created company: Hologic Inc
# Created company: Honeywell International Inc
# Created company: Hewlett Packard Enterprise
# Created company: Hp Inc
# Created company: Hormel Foods Corp
# Created company: Henry Schein Inc
# Created company: Host Hotels & Resorts Inc
# Created company: Hershey Co
# Created company: Humana Inc
# Created company: Intl Business Machines Corp
# Created company: Intercontinental Exchange In
# Created company: Idexx Laboratories Inc
# Created company: Intl Flavors & Fragrances
# Created company: Illumina Inc
# Created company: Incyte Corp
# Created company: Intel Corp
# Created company: Intuit Inc
# Created company: International Paper Co
# Created company: Interpublic Group of Cos Inc
# Created company: Iqvia Holdings Inc
# Created company: Iron Mountain Inc
# Created company: Intuitive Surgical Inc
# Created company: Illinois Tool Works
# Created company: Jacobs Solutions Inc
# Created company: Hunt (Jb) Transprt Svcs Inc
# Created company: Johnson Controls Internation
# Created company: Johnson & Johnson
# Created company: Juniper Networks Inc
# Created company: Jpmorgan Chase & Co
# Created company: Kellogg Co
# Created company: Kraft Heinz Co
# Created company: Kinder Morgan Inc
# Created company: Carmax Inc
# Created company: Coca Cola Co
# Created company: Kroger Co
# Created company: Loews Corp
# Created company: Leidos Holdings Inc
# Created company: Lennar Corp A
# Created company: Laboratory Crp of Amer Hldgs
# Created company: Lkq Corp
# Created company: Eli Lilly & Co
# Created company: Lockheed Martin Corp
# Created company: Lincoln National Corp
# Created company: Alliant Energy Corp
# Created company: Lowe S Cos Inc
# Created company: Lam Research Corp
# Created company: Southwest Airlines Co
# Created company: Las Vegas Sands Corp
# Created company: Mastercard Inc A
# Created company: Mid America Apartment Comm
# Created company: Marriott International Cl A
# Created company: Masco Corp
# Created company: Mcdonald S Corp
# Created company: Microchip Technology Inc
# Created company: Mckesson Corp
# Created company: Moody S Corp
# Created company: Mondelez International Inc A
# Created company: Medtronic Plc
# Created company: Metlife Inc
# Created company: Meta Platforms Inc Class A
# Created company: Mgm Resorts International
# Created company: Mohawk Industries Inc
# Created company: Mccormick & Co Non Vtg Shrs
# Created company: Martin Marietta Materials
# Created company: Marsh & Mclennan Cos
# Created company: 3m Co W/d
# Created company: Altria Group Inc
# Created company: Mosaic Co
# Created company: Marathon Petroleum Corp
# Created company: Merck & Co. Inc.
# Created company: Marathon Oil Corp
# Created company: Morgan Stanley
# Created company: Microsoft Corp
# Created company: Motorola Solutions Inc
# Created company: Micron Technology Inc
# Created company: Nasdaq Inc
# Created company: Nordson Corp
# Created company: Nextera Energy Inc
# Created company: Newmont Corp
# Created company: Netflix Inc
# Created company: Nike Inc Cl B
# Created company: Northrop Grumman Corp
# Created company: Servicenow Inc
# Created company: Nrg Energy Inc
# Created company: Norfolk Southern Corp
# Created company: Netapp Inc
# Created company: Northern Trust Corp
# Created company: Nucor Corp
# Created company: Nvidia Corp
# Created company: Nvr Inc
# Created company: Newell Brands Inc
# Created company: News Corp Class A
# Created company: Nxp Semiconductors Nv
# Created company: Realty Income Corp
# Created company: Omnicom Group
# Created company: Oracle Corp
# Created company: O Reilly Automotive Inc
# Created company: P G & E Corp
# Created company: Pepsico Inc
# Created company: Pfizer Inc
# Created company: Principal Financial Group
# Created company: Procter & Gamble Co
# Created company: Progressive Corp
# Created company: Pultegroup Inc
# Created company: Packaging Corp of America
# Created company: Prologis Inc
# Created company: Philip Morris International
# Created company: Pnc Financial Services Group
# Created company: Pinnacle West Capital
# Created company: Ppg Industries Inc
# Created company: Ppl Corp
# Created company: Prudential Financial Inc
# Created company: Public Storage
# Created company: Phillips 66
# Created company: Quanta Services Inc
# Created company: Pioneer Natural Resources Co
# Created company: Paypal Holdings Inc
# Created company: Qualcomm Inc
# Created company: Regeneron Pharmaceuticals
# Created company: Regions Financial Corp
# Created company: Robert Half Inc
# Created company: Raymond James Financial Inc
# Created company: Ralph Lauren Corp
# Created company: Rockwell Automation Inc
# Created company: Ross Stores Inc
# Created company: Republic Services Inc
# Created company: Starbucks Corp
# Created company: Schwab (Charles) Corp
# Created company: Sherwin Williams Co
# Created company: Jm Smucker Co
# Created company: Schlumberger Ltd
# Created company: Snap on Inc
# Created company: Southern Co
# Created company: Simon Property Group Inc
# Created company: S&p Global Inc
# Created company: Steel Dynamics Inc
# Created company: Seagate Technology Holdings
# Created company: Stanley Black & Decker Inc
# Created company: Skyworks Solutions Inc
# Created company: Synchrony Financial
# Created company: Stryker Corp
# Created company: Sysco Corp
# Created company: At&t Inc
# Created company: Molson Coors Beverage Co B
# Created company: Transdigm Group Inc
# Created company: Target Corp
# Created company: Tjx Companies Inc
# Created company: Thermo Fisher Scientific Inc
# Created company: T Mobile Us Inc
# Created company: Tapestry Inc
# Created company: Targa Resources Corp
# Created company: T Rowe Price Group Inc
# Created company: Travelers Cos Inc
# Created company: Tractor Supply Company
# Created company: Tesla Inc
# Created company: Tyson Foods Inc Cl A
# Created company: Trane Technologies Plc
# Created company: Texas Instruments Inc
# Created company: Textron Inc
# Created company: United Airlines Holdings Inc
# Created company: Udr Inc
# Created company: Universal Health Services B
# Created company: Ulta Beauty Inc
# Created company: Unitedhealth Group Inc
# Created company: Union Pacific Corp
# Created company: United Parcel Service Cl B
# Created company: United Rentals Inc
# Created company: Us Bancorp
# Created company: Visa Inc Class a Shares
# Created company: Vf Corp
# Created company: Valero Energy Corp
# Created company: Vulcan Materials Co
# Created company: Verisk Analytics Inc
# Created company: Verisign Inc
# Created company: Vertex Pharmaceuticals Inc
# Created company: Verizon Communications Inc
# Created company: Wabtec Corp
# Created company: Walgreens Boots Alliance Inc
# Created company: Welltower Inc
# Created company: Wells Fargo & Co
# Created company: Whirlpool Corp
# Created company: Waste Management Inc
# Created company: Walmart Inc
# Created company: Wr Berkley Corp
# Created company: Willis Towers Watson Plc
# Created company: Weyerhaeuser Co
# Created company: Xcel Energy Inc
# Created company: Dentsply Sirona Inc
# Created company: Xylem Inc
# Created company: Yum Brands Inc
# Created company: Zoetis Inc
